# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Standard Signal

# %%
t = np.linspace(-5, 5, 100)
y = np.abs(t) #normal signal
plt.plot(t, y, 'r')

plt.xlim(-2, 2)
plt.ylim(-1, 1)

plt.title('plot of x(t) = |t|')
plt.xlabel('time')
plt.ylabel('x(t)')
plt.style.use('dark_background')
plt.grid(True)

# %% [markdown]
# ### Scaled Signal (shrinkage, multiplication)

# %%
t = np.linspace(-5, 5, 100)
y = np.abs(t*2) #by multiply time by 2 Signal will shrink
plt.plot(t, y, 'b')

plt.xlim(-2, 2)
plt.ylim(-1, 1)

plt.title('plot of x(t) = |2t|')
plt.xlabel('time')
plt.ylabel('x(t)')
plt.style.use('dark_background')
plt.grid(True)

# %% [markdown]
# ### Scaled Signal (expansion, Division)

# %%
t = np.linspace(-5, 5, 100)
y = np.abs(t/2) #by divided time by 2 Signal will expanded
plt.plot(t, y, 'g')

plt.xlim(-2, 2)
plt.ylim(-1, 1)

plt.title('plot of x(t) = |t/2|')
plt.xlabel('time')
plt.ylabel('x(t)')
plt.style.use('dark_background')
plt.grid(True)

# %% [markdown]
# ### Comparison

# %%
t = np.linspace(-5, 5, 100)
y = np.abs(t)
#compare scaled signals
plt.plot(t, y, 'r')
plt.plot(t, y*2, 'b')
plt.plot(t, y/2, 'g')

plt.xlim(-2, 2)
plt.ylim(-1, 1)

plt.title('plot of x(t) = |t/2|')
plt.xlabel('time')
plt.ylabel('x(t)')
plt.style.use('dark_background')
plt.grid(True)
