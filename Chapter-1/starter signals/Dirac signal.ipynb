# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_position = 0
plt.axvline(x_position, color='r', linewidth=2)

plt.xlim(-1, 1)
plt.ylim(-2, 2)

plt.title('Dirac Delta Signal')
plt.xlabel('time')
plt.ylabel('δ(t)')
plt.style.use('dark_background')
plt.grid(True)
